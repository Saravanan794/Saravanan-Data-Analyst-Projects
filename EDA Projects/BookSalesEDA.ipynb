# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\Saran\Downloads\Books_Data_Clean.csv")
df.head()
# Out:
#    index  Publishing Year                        Book Name  \
# 0      0           1975.0                          Beowulf
# 1      1           1987.0                 Batman: Year One
# 2      2           2015.0                Go Set a Watchman
# 3      3           2008.0  When You Are Engulfed in Flames
# 4      4           2011.0         Daughter of Smoke & Bone
#
#                                               Author language_code  \
# 0                             Unknown, Seamus Heaney         en-US
# 1  Frank Miller, David Mazzucchelli, Richmond Lew...           eng
# 2                                         Harper Lee           eng
# 3                                      David Sedaris         en-US
# 4                                       Laini Taylor           eng
#
#   Author_Rating  Book_average_rating  Book_ratings_count          genre  \
# 0        Novice                 3.42              155903  genre fiction
# ...

# %%
df.tail()
# Out:
#       index  Publishing Year           Book Name            Author  \
# 1065   1065           2014.0       Gray Mountain      John Grisham
# 1066   1066           1989.0    The Power of One   Bryce Courtenay
# 1067   1067           1930.0  The Maltese Falcon  Dashiell Hammett
# 1068   1068           2011.0          Night Road    Kristin Hannah
# 1069   1069           1999.0            Tripwire         Lee Child
#
#      language_code Author_Rating  Book_average_rating  Book_ratings_count  \
# 1065           eng  Intermediate                 3.52               37379
# 1066           eng     Excellent                 4.34               57312
# 1067           eng  Intermediate                 3.92               58742
# 1068         en-US     Excellent                 4.17               58028
# 1069           eng     Excellent                 4.07               55251
#
#               genre  gross sales  publisher revenue  sale price  sales rank  \
# ...

# %%
df.shape
# Out:
# (1070, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1070 entries, 0 to 1069
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   index                1070 non-null   int64
#  1   Publishing Year      1069 non-null   float64
#  2   Book Name            1047 non-null   object
#  3   Author               1070 non-null   object
#  4   language_code        1017 non-null   object
#  5   Author_Rating        1070 non-null   object
#  6   Book_average_rating  1070 non-null   float64
#  7   Book_ratings_count   1070 non-null   int64
#  8   genre                1070 non-null   object
#  9   gross sales          1070 non-null   float64
#  10  publisher revenue    1070 non-null   float64
#  11  sale price           1070 non-null   float64
#  12  sales rank           1070 non-null   int64
#  13  Publisher            1070 non-null   object
#  14  units sold           1070 non-null   int64
# ...

# %%
df.describe()
# Out:
#              index  Publishing Year  Book_average_rating  Book_ratings_count  \
# count  1070.000000      1069.000000          1070.000000         1070.000000
# mean    534.500000      1971.377923             4.007000        94909.913084
# std     309.026698       185.080257             0.247244        31513.242518
# min       0.000000      -560.000000             2.970000        27308.000000
# 25%     267.250000      1985.000000             3.850000        70398.000000
# 50%     534.500000      2003.000000             4.015000        89309.000000
# 75%     801.750000      2010.000000             4.170000       113906.500000
# max    1069.000000      2016.000000             4.770000       206792.000000
#
#         gross sales  publisher revenue   sale price   sales rank    units sold
# count   1070.000000        1070.000000  1070.000000  1070.000000   1070.000000
# mean    1856.622944         843.281030     4.869561   611.652336   9676.980374
# ...

# %%
df.columns
# Out:
# Index(['index', 'Publishing Year', 'Book Name', 'Author', 'language_code',
#        'Author_Rating', 'Book_average_rating', 'Book_ratings_count', 'genre',
#        'gross sales', 'publisher revenue', 'sale price', 'sales rank',
#        'Publisher ', 'units sold'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# index                   0
# Publishing Year         0
# Book Name               0
# Author                  0
# language_code          49
# Author_Rating           0
# Book_average_rating     0
# Book_ratings_count      0
# genre                   0
# gross sales             0
# publisher revenue       0
# sale price              0
# sales rank              0
# Publisher               0
# units sold              0
# dtype: int64

# %%
df.dropna(subset="Book Name",inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.nunique()
# Out:
# index                  1047
# Publishing Year         149
# Book Name              1045
# Author                  722
# language_code             8
# Author_Rating             4
# Book_average_rating     133
# Book_ratings_count     1041
# genre                     4
# gross sales             813
# publisher revenue       595
# sale price              146
# sales rank              849
# Publisher                 9
# units sold              485
# dtype: int64

# %%
plt.hist(df["Publishing Year"])
plt.xlabel("Publishing Year")
plt.ylabel("Frequency")
plt.title("Distribution of publishing year")
plt.show()

# %%
df["genre"].value_counts().plot(kind="bar")
plt.xlabel("Genre")
plt.ylabel("Number of Books")
plt.title("Number of books in bar")
plt.show()

# %%
df.groupby("Author")["Book_average_rating"].mean().head()
# Out:
# Author
# A.A. Milne, Ernest H. Shepard     4.36
# A.S.A. Harrison                   3.30
# Abbi Glines                       4.21
# Adam Johnson                      4.06
# Adam Mansbach, Ricardo Cort̩s    4.26
# Name: Book_average_rating, dtype: float64

# %%
df.columns
# Out:
# Index(['index', 'Publishing Year', 'Book Name', 'Author', 'language_code',
#        'Author_Rating', 'Book_average_rating', 'Book_ratings_count', 'genre',
#        'gross sales', 'publisher revenue', 'sale price', 'sales rank',
#        'Publisher ', 'units sold'],
#       dtype='object')

# %%
plt.scatter(df["sale price"],df["units sold"])
plt.show()

# %%
df["genre"].value_counts().plot(kind="pie")
plt.show()

# %%
language_code = df["language_code"].value_counts().sort_values(ascending=True)
language_code
# Out:
# language_code
# nl         1
# spa        2
# ara        2
# fre        4
# en-CA      7
# en-GB     29
# en-US    228
# eng      725
# Name: count, dtype: int64

# %%
df.groupby("Publisher ")["publisher revenue"].sum()
# Out:
# Publisher
# Amazon Digital Services,  Inc.          145596.600
# Hachette Book Group                     136519.434
# HarperCollins Christian Publishing        2135.670
# HarperCollins Publishers                125983.302
# HarperCollins Publishing                  2830.806
# Macmillan                                32356.236
# Penguin Group (USA) LLC                 201897.594
# Random House LLC                        178797.222
# Simon and Schuster Digital Sales Inc     46988.352
# Name: publisher revenue, dtype: float64

# %%
df.columns
# Out:
# Index(['index', 'Publishing Year', 'Book Name', 'Author', 'language_code',
#        'Author_Rating', 'Book_average_rating', 'Book_ratings_count', 'genre',
#        'gross sales', 'publisher revenue', 'sale price', 'sales rank',
#        'Publisher ', 'units sold'],
#       dtype='object')

# %%
df.groupby("Book_average_rating")["Book_ratings_count"].mean()
# Out:
# Book_average_rating
# 2.97     53331.0
# 3.10     62760.0
# 3.21     67177.0
# 3.22     74979.0
# 3.23     63737.0
#           ...
# 4.61    117788.0
# 4.64    144822.0
# 4.65     93001.0
# 4.72    108384.0
# 4.77     73572.0
# Name: Book_ratings_count, Length: 133, dtype: float64

# %%
df.groupby("Publisher ")["publisher revenue"].sum().sort_values(ascending=False)
# Out:
# Publisher
# Penguin Group (USA) LLC                 201897.594
# Random House LLC                        178797.222
# Amazon Digital Services,  Inc.          145596.600
# Hachette Book Group                     136519.434
# HarperCollins Publishers                125983.302
# Simon and Schuster Digital Sales Inc     46988.352
# Macmillan                                32356.236
# HarperCollins Publishing                  2830.806
# HarperCollins Christian Publishing        2135.670
# Name: publisher revenue, dtype: float64

# %%
df.columns
# Out:
# Index(['index', 'Publishing Year', 'Book Name', 'Author', 'language_code',
#        'Author_Rating', 'Book_average_rating', 'Book_ratings_count', 'genre',
#        'gross sales', 'publisher revenue', 'sale price', 'sales rank',
#        'Publisher ', 'units sold'],
#       dtype='object')

# %%
plt.scatter(df["Book_average_rating"],df["Book_ratings_count"],color="red")
plt.xlabel("Book average rating")
plt.ylabel("Book average count")
plt.title("Scatter plot of Book average rating vs Book average count ")
plt.show()

# %%
gross_sales_by_author = df.groupby("Author")["gross sales"].sum()
gross_sales_by_author.sort_values(ascending=False).head(5).plot(kind = "bar",color = "green")
plt.xlabel("Author")
plt.ylabel("Total gross sales")
plt.title("Total gross sales of each author")
plt.show()
